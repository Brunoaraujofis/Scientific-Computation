# %% [markdown]
# from scipy import *
# from matplotlib import *
# import numpy as np
# import matplotlib.pyplot as plt

# %%
from scipy import *
from matplotlib import * 
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Usado para agrupar objetos. A principal diferença entre Container Types esta  na forma que os elementos individuais podem ser acessados e nas operações que podem ser definidas.
